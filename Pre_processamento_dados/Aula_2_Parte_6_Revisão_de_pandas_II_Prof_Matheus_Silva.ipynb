# %% [markdown]
# Q1

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
np.random.seed(0)
amostras = 1000
datas = pd.date_range('2020-01-01', '2020-01-31')
sexo = ['M', 'F']
estado = [
'AC', 'AL', 'AP', 'AM', 'BA', 'CE', 'DF', 'ES', 'GO',
'MA', 'MT', 'MS', 'MG', 'PA', 'PB', 'PR', 'PE', 'PI',
'RJ', 'RN', 'RS', 'RO', 'RR', 'SC', 'SP', 'SE', 'TO'
]

# %%
len(estado)
# Out:
# 27

# %%
df = pd.DataFrame({
    'idade': np.random.randint(0, 101, amostras),
    'data': np.random.choice(datas, amostras),
    'nota': np.random.uniform(0,1001, amostras),
    'sexo': np.random.choice(sexo, amostras),
    'estado': np.random.choice(estado, amostras)

})
df
# Out:
#      idade       data        nota sexo estado
# 0       44 2020-01-15  102.548728    F     RR
# 1       47 2020-01-06  397.422858    F     RS
# 2       64 2020-01-23  276.926380    M     RR
# 3       67 2020-01-20  506.849262    F     MT
# 4       67 2020-01-16  350.247578    F     SP
# ..     ...        ...         ...  ...    ...
# 995     79 2020-01-03  320.127143    F     MS
# 996     41 2020-01-28  817.641967    F     AP
# 997     17 2020-01-18  540.076142    F     SP
# 998     80 2020-01-08   45.896205    M     PA
# 999     43 2020-01-08  464.358569    M     ES
#
# [1000 rows x 5 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   idade   1000 non-null   int64
#  1   data    1000 non-null   datetime64[ns]
#  2   nota    1000 non-null   float64
#  3   sexo    1000 non-null   object
#  4   estado  1000 non-null   object
# dtypes: datetime64[ns](1), float64(1), int64(1), object(2)
# memory usage: 39.2+ KB

# %%
df.describe(include='all')
# Out:
# <ipython-input-6-174ba9bf1a5c>:1: FutureWarning: Treating datetime data as categorical rather than numeric in `.describe` is deprecated and will be removed in a future version of pandas. Specify `datetime_is_numeric=True` to silence this warning and adopt the future behavior now.
#   df.describe(include='all')
#               idade                 data         nota  sexo estado
# count   1000.000000                 1000  1000.000000  1000   1000
# unique          NaN                   31          NaN     2     27
# top             NaN  2020-01-20 00:00:00          NaN     F     SP
# freq            NaN                   42          NaN   512     55
# first           NaN  2020-01-01 00:00:00          NaN   NaN    NaN
# last            NaN  2020-01-31 00:00:00          NaN   NaN    NaN
# mean      50.130000                  NaN   510.172118   NaN    NaN
# std       29.476057                  NaN   295.038249   NaN    NaN
# ...

# %% [markdown]
# Q2

# %%
faltantes = df['nota'].sample(frac=.2, random_state=0).index
df.loc[faltantes, 'nota'] = np.nan
df
# Out:
#      idade       data        nota sexo estado
# 0       44 2020-01-15  102.548728    F     RR
# 1       47 2020-01-06         NaN    F     RS
# 2       64 2020-01-23  276.926380    M     RR
# 3       67 2020-01-20  506.849262    F     MT
# 4       67 2020-01-16  350.247578    F     SP
# ..     ...        ...         ...  ...    ...
# 995     79 2020-01-03  320.127143    F     MS
# 996     41 2020-01-28         NaN    F     AP
# 997     17 2020-01-18  540.076142    F     SP
# 998     80 2020-01-08   45.896205    M     PA
# 999     43 2020-01-08         NaN    M     ES
#
# [1000 rows x 5 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   idade   1000 non-null   int64
#  1   data    1000 non-null   datetime64[ns]
#  2   nota    800 non-null    float64
#  3   sexo    1000 non-null   object
#  4   estado  1000 non-null   object
# dtypes: datetime64[ns](1), float64(1), int64(1), object(2)
# memory usage: 39.2+ KB

# %%
df.loc[df['nota'].isna(), 'nota'] = 0
df
# Out:
#      idade       data        nota sexo estado
# 0       44 2020-01-15  102.548728    F     RR
# 1       47 2020-01-06    0.000000    F     RS
# 2       64 2020-01-23  276.926380    M     RR
# 3       67 2020-01-20  506.849262    F     MT
# 4       67 2020-01-16  350.247578    F     SP
# ..     ...        ...         ...  ...    ...
# 995     79 2020-01-03  320.127143    F     MS
# 996     41 2020-01-28    0.000000    F     AP
# 997     17 2020-01-18  540.076142    F     SP
# 998     80 2020-01-08   45.896205    M     PA
# 999     43 2020-01-08    0.000000    M     ES
#
# [1000 rows x 5 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   idade   1000 non-null   int64
#  1   data    1000 non-null   datetime64[ns]
#  2   nota    1000 non-null   float64
#  3   sexo    1000 non-null   object
#  4   estado  1000 non-null   object
# dtypes: datetime64[ns](1), float64(1), int64(1), object(2)
# memory usage: 39.2+ KB

# %%
me_18 = df['idade'] < 18
ma_80 = df['idade'] > 80
filtro = me_18 | ma_80
df[filtro]
# Out:
#      idade       data        nota sexo estado
# 5        9 2020-01-23    0.000000    F     RR
# 6       83 2020-01-14   24.601601    M     SE
# 9       87 2020-01-02  268.977738    F     BA
# 11      88 2020-01-24  956.523962    M     PI
# 12      88 2020-01-27  316.866760    M     DF
# ..     ...        ...         ...  ...    ...
# 991     89 2020-01-07  115.039274    M     SC
# 992     89 2020-01-29  724.796599    F     PA
# 993      6 2020-01-13    0.000000    F     SC
# 994     88 2020-01-12  176.279942    F     AL
# 997     17 2020-01-18  540.076142    F     SP
#
# [376 rows x 5 columns]

# %%
df.drop(df[filtro].index, inplace=True)
df
# Out:
#      idade       data        nota sexo estado
# 0       44 2020-01-15  102.548728    F     RR
# 1       47 2020-01-06    0.000000    F     RS
# 2       64 2020-01-23  276.926380    M     RR
# 3       67 2020-01-20  506.849262    F     MT
# 4       67 2020-01-16  350.247578    F     SP
# ..     ...        ...         ...  ...    ...
# 990     26 2020-01-11    0.000000    M     RO
# 995     79 2020-01-03  320.127143    F     MS
# 996     41 2020-01-28    0.000000    F     AP
# 998     80 2020-01-08   45.896205    M     PA
# 999     43 2020-01-08    0.000000    M     ES
#
# [624 rows x 5 columns]

# %%
def aprovado(nota):
  if nota >= 600:
    return 'Aprovado'
  else:
    return 'Reprovado'

aprovado(600), aprovado(400)
# Out:
# ('Aprovado', 'Reprovado')

# %%
df['aprovado'] = df['nota'].apply(aprovado)
df
# Out:
#      idade       data        nota sexo estado   aprovado
# 0       44 2020-01-15  102.548728    F     RR  Reprovado
# 1       47 2020-01-06    0.000000    F     RS  Reprovado
# 2       64 2020-01-23  276.926380    M     RR  Reprovado
# 3       67 2020-01-20  506.849262    F     MT  Reprovado
# 4       67 2020-01-16  350.247578    F     SP  Reprovado
# ..     ...        ...         ...  ...    ...        ...
# 990     26 2020-01-11    0.000000    M     RO  Reprovado
# 995     79 2020-01-03  320.127143    F     MS  Reprovado
# 996     41 2020-01-28    0.000000    F     AP  Reprovado
# 998     80 2020-01-08   45.896205    M     PA  Reprovado
# 999     43 2020-01-08    0.000000    M     ES  Reprovado
#
# [624 rows x 6 columns]

# %%
df['dia_semana'] = df['data'].dt.weekday
df
# Out:
#      idade       data        nota sexo estado   aprovado  dia_semana
# 0       44 2020-01-15  102.548728    F     RR  Reprovado           2
# 1       47 2020-01-06    0.000000    F     RS  Reprovado           0
# 2       64 2020-01-23  276.926380    M     RR  Reprovado           3
# 3       67 2020-01-20  506.849262    F     MT  Reprovado           0
# 4       67 2020-01-16  350.247578    F     SP  Reprovado           3
# ..     ...        ...         ...  ...    ...        ...         ...
# 990     26 2020-01-11    0.000000    M     RO  Reprovado           5
# 995     79 2020-01-03  320.127143    F     MS  Reprovado           4
# 996     41 2020-01-28    0.000000    F     AP  Reprovado           1
# 998     80 2020-01-08   45.896205    M     PA  Reprovado           2
# 999     43 2020-01-08    0.000000    M     ES  Reprovado           2
#
# [624 rows x 7 columns]

# %%
mapa = {
    0: 'segunda',
    1: 'terça',
    2: 'quarta',
    3: 'quinta',
    4: 'sexta',
    5: 'sabado',
    6: 'domingo',
}
df['dia_semana'] = df['dia_semana'].map(mapa)
df
# Out:
#      idade       data        nota sexo estado   aprovado dia_semana
# 0       44 2020-01-15  102.548728    F     RR  Reprovado     quarta
# 1       47 2020-01-06    0.000000    F     RS  Reprovado    segunda
# 2       64 2020-01-23  276.926380    M     RR  Reprovado     quinta
# 3       67 2020-01-20  506.849262    F     MT  Reprovado    segunda
# 4       67 2020-01-16  350.247578    F     SP  Reprovado     quinta
# ..     ...        ...         ...  ...    ...        ...        ...
# 990     26 2020-01-11    0.000000    M     RO  Reprovado     sabado
# 995     79 2020-01-03  320.127143    F     MS  Reprovado      sexta
# 996     41 2020-01-28    0.000000    F     AP  Reprovado      terça
# 998     80 2020-01-08   45.896205    M     PA  Reprovado     quarta
# 999     43 2020-01-08    0.000000    M     ES  Reprovado     quarta
#
# [624 rows x 7 columns]

# %%
df.loc[df['estado'] == 'AC', 'sexo'].value_counts()
# Out:
# M    20
# F    12
# Name: sexo, dtype: int64

# %%
pd.crosstab(df['estado'], df['sexo'])
# Out:
# sexo     F   M
# estado
# AC      12  20
# AL      14   7
# AM       9  11
# AP       9  11
# BA       7  11
# CE      13  18
# DF      12  12
# ES      16  11
# GO      13  11
# MA      12   9
# MG      10  12
# MS      10  12
# MT      15  12
# PA       9  13
# PB       9   6
# PE      14  12
# PI       8  11
# PR      13   8
# RJ      15   6
# RN       7   9
# RO      10  11
# RR      20   6
# RS      12  15
# SC      12  11
# SE      13  11
# SP      16  18
# TO      11   9

# %%
alunos_aprovados = df['aprovado'] == 'Aprovado'
df[alunos_aprovados]
# Out:
#      idade       data        nota sexo estado  aprovado dia_semana
# 7       21 2020-01-12  634.620908    F     RJ  Aprovado    domingo
# 10      70 2020-01-08  801.055859    F     AC  Aprovado     quarta
# 15      65 2020-01-16  634.615635    F     AC  Aprovado     quinta
# 16      39 2020-01-23  751.783332    M     PE  Aprovado     quinta
# 24      72 2020-01-09  799.487938    M     SC  Aprovado     quinta
# ..     ...        ...         ...  ...    ...       ...        ...
# 970     51 2020-01-31  755.538677    M     TO  Aprovado      sexta
# 972     59 2020-01-16  668.301435    M     AP  Aprovado     quinta
# 983     65 2020-01-01  990.514608    M     MT  Aprovado     quarta
# 984     23 2020-01-23  645.059980    F     RS  Aprovado     quinta
# 988     37 2020-01-29  708.783008    M     CE  Aprovado     quarta
#
# [204 rows x 7 columns]

# %%
df['aprovado'].value_counts()
# Out:
# Reprovado    420
# Aprovado     204
# Name: aprovado, dtype: int64

# %%
df.loc[alunos_aprovados, 'sexo'].value_counts().plot(kind='pie')
# Out:
# <Axes: ylabel='sexo'>

# %%
df.loc[alunos_aprovados, 'estado'].value_counts(normalize=True).plot(kind='bar')
# Out:
# <Axes: >

# %%
import seaborn as sns
sns.scatterplot(data=df[alunos_aprovados], x='idade', y='nota', hue='sexo');

# %%
df['dia_semana'].value_counts().plot(kind='bar');

# %%
df['data'].dt.day.value_counts().sort_index().plot(kind='bar')
# Out:
# <Axes: >

# %%
#df.plot(kind='scatter', y='nota', x='dia_semana');
sns.stripplot(data=df, y='nota', x='dia_semana');

# %%
df.sort_values('nota', ascending=False)[:100].to_csv('convocados.csv')
