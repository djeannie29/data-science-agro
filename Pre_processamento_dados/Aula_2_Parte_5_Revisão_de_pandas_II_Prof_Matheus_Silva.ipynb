# %%
import numpy as np
import pandas as pd

# %%
lista = [1,2,3,4]
array = np.array(lista)
serie = pd.Series(array, name = 'numeros')

# %%
lista
# Out:
# [1, 2, 3, 4]

# %%
array
# Out:
# array([1, 2, 3, 4])

# %%
serie
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# Name: numeros, dtype: int64

# %%
help(pd.date_range)
# Out:
# Help on function date_range in module pandas.core.indexes.datetimes:
#
# date_range(start=None, end=None, periods=None, freq=None, tz=None, normalize: 'bool' = False, name: 'Hashable' = None, closed: "Literal['left', 'right'] | None | lib.NoDefault" = <no_default>, inclusive: 'IntervalClosedType | None' = None, **kwargs) -> 'DatetimeIndex'
#     Return a fixed frequency DatetimeIndex.
#
#     Returns the range of equally spaced time points (where the difference between any
#     two adjacent points is specified by the given frequency) such that they all
#     satisfy `start <[=] x <[=] end`, where the first one and the last one are, resp.,
#     the first and last time points in that range that fall on the boundary of ``freq``
#     (if given as a frequency string) or that are valid for ``freq`` (if given as a
#     :class:`pandas.tseries.offsets.DateOffset`). (If exactly one of ``start``,
#     ``end``, or ``freq`` is *not* specified, this missing parameter can be computed
# ...

# %%
datas = pd.date_range('2022-01-01', '2022-12-31')

# %%
df = pd.DataFrame({
    'nulos': np.nan #None
}, index=datas).sort_index(ascending=False) #sort_values(by=coluna)

# %%
df.loc['2022-11-01':'2022-12-01']
# Out:
#             nulos
# 2022-12-01    NaN
# 2022-11-30    NaN
# 2022-11-29    NaN
# 2022-11-28    NaN
# 2022-11-27    NaN
# 2022-11-26    NaN
# 2022-11-25    NaN
# 2022-11-24    NaN
# 2022-11-23    NaN
# 2022-11-22    NaN
# 2022-11-21    NaN
# 2022-11-20    NaN
# 2022-11-19    NaN
# 2022-11-18    NaN
# 2022-11-17    NaN
# 2022-11-16    NaN
# 2022-11-15    NaN
# 2022-11-14    NaN
# 2022-11-13    NaN
# 2022-11-12    NaN
# 2022-11-11    NaN
# 2022-11-10    NaN
# 2022-11-09    NaN
# 2022-11-08    NaN
# 2022-11-07    NaN
# 2022-11-06    NaN
# 2022-11-05    NaN
# 2022-11-04    NaN
# 2022-11-03    NaN
# 2022-11-02    NaN
# 2022-11-01    NaN

# %%
df.iloc[-10:] #linha, coluna
# Out:
#             nulos
# 2022-01-10    NaN
# 2022-01-09    NaN
# 2022-01-08    NaN
# 2022-01-07    NaN
# 2022-01-06    NaN
# 2022-01-05    NaN
# 2022-01-04    NaN
# 2022-01-03    NaN
# 2022-01-02    NaN
# 2022-01-01    NaN

# %%
df['vendas'] = np.random.randint(100, 200, 365)
df
# Out:
#             nulos  vendas
# 2022-12-31    NaN     118
# 2022-12-30    NaN     161
# 2022-12-29    NaN     180
# 2022-12-28    NaN     144
# 2022-12-27    NaN     100
# ...           ...     ...
# 2022-01-05    NaN     197
# 2022-01-04    NaN     170
# 2022-01-03    NaN     141
# 2022-01-02    NaN     157
# 2022-01-01    NaN     141
#
# [365 rows x 2 columns]

# %%
estado = ['SP', 'MG', 'GO']

# %%
df['fazenda'] = np.random.choice(estado, 365, p=[.6, .3, .1])
df
# Out:
#             nulos  vendas fazenda
# 2022-12-31    NaN     118      SP
# 2022-12-30    NaN     161      SP
# 2022-12-29    NaN     180      GO
# 2022-12-28    NaN     144      SP
# 2022-12-27    NaN     100      GO
# ...           ...     ...     ...
# 2022-01-05    NaN     197      GO
# 2022-01-04    NaN     170      MG
# 2022-01-03    NaN     141      SP
# 2022-01-02    NaN     157      SP
# 2022-01-01    NaN     141      GO
#
# [365 rows x 3 columns]

# %%
df['fazenda'].value_counts(normalize=True)
# Out:
# SP    0.616438
# MG    0.254795
# GO    0.128767
# Name: fazenda, dtype: float64

# %%
df.loc['2022-12-25':'2022-12-31', 'vendas'] = df.loc['2022-12-25':'2022-12-31', 'vendas'] + 50

# %%
df.loc['2022-12-25':'2022-12-31', 'vendas']
# Out:
# 2022-12-31    268
# 2022-12-30    311
# 2022-12-29    330
# 2022-12-28    294
# 2022-12-27    250
# 2022-12-26    304
# 2022-12-25    251
# Freq: -1D, Name: vendas, dtype: int64

# %%
df['year'] = df.index.to_series().dt.year
df['month'] = df.index.to_series().dt.month
df
# Out:
#             nulos  vendas fazenda  year  month
# 2022-12-31    NaN     268      SP  2022     12
# 2022-12-30    NaN     311      SP  2022     12
# 2022-12-29    NaN     330      GO  2022     12
# 2022-12-28    NaN     294      SP  2022     12
# 2022-12-27    NaN     250      GO  2022     12
# ...           ...     ...     ...   ...    ...
# 2022-01-05    NaN     197      GO  2022      1
# 2022-01-04    NaN     170      MG  2022      1
# 2022-01-03    NaN     141      SP  2022      1
# 2022-01-02    NaN     157      SP  2022      1
# 2022-01-01    NaN     141      GO  2022      1
#
# [365 rows x 5 columns]

# %%
df['fazenda'].str.lower()
# Out:
# 2022-12-31    sp
# 2022-12-30    sp
# 2022-12-29    go
# 2022-12-28    sp
# 2022-12-27    go
#               ..
# 2022-01-05    go
# 2022-01-04    mg
# 2022-01-03    sp
# 2022-01-02    sp
# 2022-01-01    go
# Freq: -1D, Name: fazenda, Length: 365, dtype: object

# %%
df['fazenda']
# Out:
# 2022-12-31    SP
# 2022-12-30    SP
# 2022-12-29    GO
# 2022-12-28    SP
# 2022-12-27    GO
#               ..
# 2022-01-05    GO
# 2022-01-04    MG
# 2022-01-03    SP
# 2022-01-02    SP
# 2022-01-01    GO
# Freq: -1D, Name: fazenda, Length: 365, dtype: object

# %%
df.sample(100)
# Out:
#             nulos  vendas fazenda  year  month
# 2022-03-23    NaN     114      SP  2022      3
# 2022-01-29    NaN     161      GO  2022      1
# 2022-03-17    NaN     120      SP  2022      3
# 2022-04-04    NaN     116      GO  2022      4
# 2022-05-18    NaN     195      SP  2022      5
# ...           ...     ...     ...   ...    ...
# 2022-06-11    NaN     198      SP  2022      6
# 2022-02-02    NaN     183      SP  2022      2
# 2022-12-16    NaN     131      SP  2022     12
# 2022-12-10    NaN     196      MG  2022     12
# 2022-03-13    NaN     144      MG  2022      3
#
# [100 rows x 5 columns]

# %%
df.sample(frac=.3, random_state=0)
# Out:
#             nulos  vendas fazenda  year  month
# 2022-09-16    NaN     169      SP  2022      9
# 2022-04-16    NaN     145      MG  2022      4
# 2022-11-16    NaN     101      MG  2022     11
# 2022-12-05    NaN     198      SP  2022     12
# 2022-10-14    NaN     162      MG  2022     10
# ...           ...     ...     ...   ...    ...
# 2022-05-28    NaN     130      SP  2022      5
# 2022-08-08    NaN     146      SP  2022      8
# 2022-02-16    NaN     132      SP  2022      2
# 2022-05-11    NaN     179      SP  2022      5
# 2022-05-27    NaN     156      SP  2022      5
#
# [110 rows x 5 columns]

# %%
mapa = {
     1: 'jan',
     2: 'fev',
     3: 'mar',
     12: 'dez'
}
df['month'].map(mapa)
# Out:
# 2022-12-31    dez
# 2022-12-30    dez
# 2022-12-29    dez
# 2022-12-28    dez
# 2022-12-27    dez
#              ...
# 2022-01-05    jan
# 2022-01-04    jan
# 2022-01-03    jan
# 2022-01-02    jan
# 2022-01-01    jan
# Freq: -1D, Name: month, Length: 365, dtype: object

# %%
df['month'].replace(mapa)
# Out:
# 2022-12-31    dez
# 2022-12-30    dez
# 2022-12-29    dez
# 2022-12-28    dez
# 2022-12-27    dez
#              ...
# 2022-01-05    jan
# 2022-01-04    jan
# 2022-01-03    jan
# 2022-01-02    jan
# 2022-01-01    jan
# Freq: -1D, Name: month, Length: 365, dtype: object

# %%
np.random.uniform(0,100, 100)
# Out:
# array([ 9.62502492, 91.52234377, 58.32417962, 12.54222547, 64.85333451,
#        44.63355177, 76.69117619, 44.98536834,  7.64901916, 72.68397282,
#        74.00690945, 54.34530697, 25.91066489, 53.74326374, 59.90859602,
#        53.00764734, 19.0137281 , 75.06364804, 73.57492864, 43.08540067,
#        47.27834142, 71.50148732, 11.15427641, 37.19236202, 65.4226307 ,
#        10.67164024, 79.91149114, 37.59350595, 77.59676921, 47.62562512,
#        82.78926931, 53.14952723, 70.60820727, 73.45174159, 13.15796177,
#        26.69568745, 51.19062491,  9.41901601, 12.00213267, 32.01345651,
#        88.00492012,  5.58395566, 43.39004769, 62.79071394, 75.51141659,
#        21.44822272, 20.70188581,  1.07899042, 35.90482995, 47.9770259 ,
#        39.90565859,  2.72320977, 54.62904206, 15.30521826, 59.19700849,
#        61.89210209, 86.22157926, 36.64076872, 44.74231338, 62.2210992 ,
#        15.12191103, 19.62998265, 37.95345085,  6.23434146, 20.63888602,
# ...

# %%
df
# Out:
#             nulos  vendas fazenda  year  month
# 2022-12-31    NaN     268      SP  2022     12
# 2022-12-30    NaN     311      SP  2022     12
# 2022-12-29    NaN     330      GO  2022     12
# 2022-12-28    NaN     294      SP  2022     12
# 2022-12-27    NaN     250      GO  2022     12
# ...           ...     ...     ...   ...    ...
# 2022-01-05    NaN     197      GO  2022      1
# 2022-01-04    NaN     170      MG  2022      1
# 2022-01-03    NaN     141      SP  2022      1
# 2022-01-02    NaN     157      SP  2022      1
# 2022-01-01    NaN     141      GO  2022      1
#
# [365 rows x 5 columns]

# %%
df.isnull()
# Out:
#             nulos  vendas  fazenda   year  month
# 2022-12-31   True   False    False  False  False
# 2022-12-30   True   False    False  False  False
# 2022-12-29   True   False    False  False  False
# 2022-12-28   True   False    False  False  False
# 2022-12-27   True   False    False  False  False
# ...           ...     ...      ...    ...    ...
# 2022-01-05   True   False    False  False  False
# 2022-01-04   True   False    False  False  False
# 2022-01-03   True   False    False  False  False
# 2022-01-02   True   False    False  False  False
# 2022-01-01   True   False    False  False  False
#
# [365 rows x 5 columns]

# %%
df.fillna(-1)
# Out:
#             nulos  vendas fazenda  year  month
# 2022-12-31   -1.0     268      SP  2022     12
# 2022-12-30   -1.0     311      SP  2022     12
# 2022-12-29   -1.0     330      GO  2022     12
# 2022-12-28   -1.0     294      SP  2022     12
# 2022-12-27   -1.0     250      GO  2022     12
# ...           ...     ...     ...   ...    ...
# 2022-01-05   -1.0     197      GO  2022      1
# 2022-01-04   -1.0     170      MG  2022      1
# 2022-01-03   -1.0     141      SP  2022      1
# 2022-01-02   -1.0     157      SP  2022      1
# 2022-01-01   -1.0     141      GO  2022      1
#
# [365 rows x 5 columns]

# %%
df.to_csv('arquivo.csv')
