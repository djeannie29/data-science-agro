# %%
import pandas as pd
pd.read_csv('/content/exemplo milho editado.csv.csv')
# Out:
#                                    Id  Date_time  Latitude  Longitude  Elev_m  \
# 22  06/27/2005 03:06:33 PM -17.824600 -52.083165     860.5          0       7
# 23  06/27/2005 03:06:36 PM -17.824625 -52.083153     860.5          0       7
# 24  06/27/2005 03:06:37 PM -17.824646 -52.083143     860.5          0       7
# 30  06/27/2005 03:06:50 PM -17.824796 -52.083073     860.7          0       7
# 31  06/27/2005 03:06:52 PM -17.824821 -52.083061     860.9          0       7
# ...                               ...        ...       ...        ...     ...
# 294 06/02/2005 01:56:43 PM -17.826555 -52.086723     868.2          0       7
# 296 06/02/2005 01:56:46 PM -17.826560 -52.086783     868.3          0       7
# 309 06/02/2005 01:57:13 PM -17.826433 -52.086741     868.0          0       7
# 310 06/02/2005 01:57:14 PM -17.826435 -52.086748     867.8          0       7
# 311 06/02/2005 01:57:16 PM -17.826436 -52.086753     867.6          0       7
#
# ...
